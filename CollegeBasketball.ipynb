# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('databases/cbb.csv', header=None, skiprows=1)

header = pd.read_csv('databases/cbb.csv', nrows=1, header=None).iloc[0].tolist()
df.columns = header

display(df)
# Out:
#                 TEAM  CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  \
# 0     North Carolina   ACC  40  33  123.3   94.9   0.9531   52.6   48.1  15.4
# 1          Wisconsin   B10  40  36  129.1   93.6   0.9758   54.8   47.7  12.4
# 2           Michigan   B10  40  33  114.4   90.4   0.9375   53.9   47.7  14.0
# 3         Texas Tech   B12  38  31  115.2   85.2   0.9696   53.5   43.0  17.7
# 4            Gonzaga   WCC  39  37  117.8   86.3   0.9728   56.6   41.1  16.2
# ...              ...   ...  ..  ..    ...    ...      ...    ...    ...   ...
# 3518          Toledo   MAC  34  27  119.9  109.6   0.7369   56.3   52.9  13.6
# 3519         Liberty  ASun  33  27  111.4   97.3   0.8246   55.5   49.3  16.0
# 3520     Utah Valley   WAC  34  28  107.1   94.6   0.8065   51.7   44.0  19.3
# 3521             UAB  CUSA  38  29  112.4   97.0   0.8453   50.3   47.3  17.3
# 3522     North Texas  CUSA  36  31  110.0   93.8   0.8622   51.2   44.5  19.8
#
# ...

# %%
#display(df[df['SEED']==na])
#df.loc[:, df.isna().any()]
#df.loc[:, df['SEED'].isna()]
#df.loc[:, df[['SEED']].isna().any()]
df.loc[df['YEAR']==2016]
df.loc[(df['SEED'].isna()) & (df['YEAR']==2016)]
# Out:
#                    TEAM CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D  \
# 67             Davidson  A10  32  19  113.0  106.0   0.6767   52.0   52.0
# 68             Duquesne  A10  33  16  108.2  105.1   0.5851   53.9   49.4
# 69              Fordham  A10  30  16  101.8  100.4   0.5388   51.5   51.4
# 70         George Mason  A10  32  11  101.4  103.1   0.4507   45.1   48.4
# 71    George Washington  A10  38  28  114.9   99.1   0.8454   50.8   48.7
# ...                 ...  ...  ..  ..    ...    ...      ...    ...    ...
# 1443           Portland  WCC  31  11  107.6  109.2   0.4588   49.9   52.4
# 1444       Saint Mary's  WCC  34  28  117.6   98.6   0.8830   58.4   46.2
# 1445          San Diego  WCC  29   8   92.8  101.0   0.2743   45.2   50.0
# 1446      San Francisco  WCC  29  14  105.5  109.6   0.3908   50.0   51.7
# 1447        Santa Clara  WCC  30  10  101.1  107.2   0.3383   47.9   50.8
#
#        TOR  ...  FTRD  2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  POSTSEASON  SEED  \
# ...

# %%
display(df[df['YEAR']==2023])
# Out:
#              TEAM  CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  \
# 3160       Kansas   B12  36  28  113.8   92.3   0.9177   52.6   47.0  17.5
# 3161       Purdue   B10  35  29  117.9   93.7   0.9333   51.8   47.2  17.2
# 3162      Alabama   SEC  37  31  116.1   89.0   0.9548   52.1   41.3  18.7
# 3163      Houston  Amer  37  33  117.3   90.3   0.9532   52.3   42.7  15.4
# 3164        Texas   B12  38  29  116.1   91.8   0.9371   53.3   48.1  16.3
# ...           ...   ...  ..  ..    ...    ...      ...    ...    ...   ...
# 3518       Toledo   MAC  34  27  119.9  109.6   0.7369   56.3   52.9  13.6
# 3519      Liberty  ASun  33  27  111.4   97.3   0.8246   55.5   49.3  16.0
# 3520  Utah Valley   WAC  34  28  107.1   94.6   0.8065   51.7   44.0  19.3
# 3521          UAB  CUSA  38  29  112.4   97.0   0.8453   50.3   47.3  17.3
# 3522  North Texas  CUSA  36  31  110.0   93.8   0.8622   51.2   44.5  19.8
#
# ...

# %%
df.groupby('TEAM')['SEED'].sum()
# Out:
# TEAM
# Abilene Christian    29.0
# Air Force             0.0
# Akron                25.0
# Alabama              18.0
# Alabama A&M           0.0
#                      ...
# Wright St.           30.0
# Wyoming              24.0
# Xavier               35.0
# Yale                 40.0
# Youngstown St.        0.0
# Name: SEED, Length: 368, dtype: float64

# %%
df[(df['YEAR']==2017)]
# Out:
#                 TEAM CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  \
# 4            Gonzaga  WCC  39  37  117.8   86.3   0.9728   56.6   41.1  16.2
# 9     North Carolina  ACC  39  33  121.0   91.5   0.9615   51.7   48.1  16.2
# 23            Kansas  B12  36  31  121.5   94.5   0.9472   56.1   48.1  17.6
# 26            Xavier   BE  38  24  115.6   97.9   0.8713   51.9   51.6  18.4
# 29           Florida  SEC  36  27  116.6   88.9   0.9576   51.6   45.8  16.9
# ...              ...  ...  ..  ..    ...    ...      ...    ...    ...   ...
# 2420          Baylor  B12  34  27  116.4   93.9   0.9226   52.5   46.1  20.6
# 2421   West Virginia  B12  37  28  115.4   89.3   0.9498   51.3   48.8  17.0
# 2424          Butler   BE  34  25  117.7   96.9   0.9038   54.6   50.8  15.0
# 2429         Arizona  P12  37  32  117.6   95.6   0.9157   53.7   47.7  16.6
# 2430            UCLA  P12  36  31  122.8   99.6   0.9175   59.8   48.7  15.1
#
# ...

# %%
df.dtypes
# Out:
# TEAM           object
# CONF           object
# G               int64
# W               int64
# ADJOE         float64
# ADJDE         float64
# BARTHAG       float64
# EFG_O         float64
# EFG_D         float64
# TOR           float64
# TORD          float64
# ORB           float64
# DRB           float64
# FTR           float64
# FTRD          float64
# 2P_O          float64
# 2P_D          float64
# 3P_O          float64
# 3P_D          float64
# ADJ_T         float64
# WAB           float64
# POSTSEASON     object
# SEED          float64
# YEAR            int64
# dtype: object

# %%
df[df['TEAM']=='Lindenwood'].sort_values(by='YEAR').plot(x='YEAR', y='W')
plt.show()
display(df[df['TEAM']=='Dixie St.'])
# Out:
#            TEAM CONF   G  W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  ...  \
# 2601  Dixie St.  WAC  19  8   91.6  106.0    0.157   45.5   52.0  20.9  ...
#
#       FTRD  2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  POSTSEASON  SEED  YEAR
# 2601  36.5  45.9  53.9  29.7  32.5   72.9 -10.1         NaN   NaN  2021
#
# [1 rows x 24 columns]

# %%
#plt.figure(figsize=(10, 6))

#for team in df['TEAM'].unique():  # Iterujemy po unikalnych drużynach
#    print(team)
#    df[df['TEAM'] == team].sort_values(by='YEAR').plot(x='YEAR', y='W', label=team)  # Dodajemy tytuł wykresu
    
#plt.show()  # Wyświetlamy wykres dla każdej drużyny osobno

# %%
team_data = df[df['TEAM'] == team].sort_values(by='YEAR')
team_data.plot(x='YEAR', y='W', marker='o')
# Out:
# <Axes: xlabel='YEAR'>

# %%
df[df['TEAM'] == team].sort_values(by='YEAR').plot(x='YEAR', y='W')
# Out:
# <Axes: xlabel='YEAR'>

# %%
df['YEAR'].nunique()
# Out:
# 10

# %%
df_grouped = df.groupby('TEAM')['YEAR'].size()
teams_with_10_records = df_grouped[df_grouped == 10]
df_all_years = df[df['TEAM'].isin(teams_with_10_records.index)]

# %%
df_all_years
# Out:
#                 TEAM  CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  \
# 0     North Carolina   ACC  40  33  123.3   94.9   0.9531   52.6   48.1  15.4
# 1          Wisconsin   B10  40  36  129.1   93.6   0.9758   54.8   47.7  12.4
# 2           Michigan   B10  40  33  114.4   90.4   0.9375   53.9   47.7  14.0
# 3         Texas Tech   B12  38  31  115.2   85.2   0.9696   53.5   43.0  17.7
# 4            Gonzaga   WCC  39  37  117.8   86.3   0.9728   56.6   41.1  16.2
# ...              ...   ...  ..  ..    ...    ...      ...    ...    ...   ...
# 3518          Toledo   MAC  34  27  119.9  109.6   0.7369   56.3   52.9  13.6
# 3519         Liberty  ASun  33  27  111.4   97.3   0.8246   55.5   49.3  16.0
# 3520     Utah Valley   WAC  34  28  107.1   94.6   0.8065   51.7   44.0  19.3
# 3521             UAB  CUSA  38  29  112.4   97.0   0.8453   50.3   47.3  17.3
# 3522     North Texas  CUSA  36  31  110.0   93.8   0.8622   51.2   44.5  19.8
#
# ...

# %%
df
# Out:
#                 TEAM  CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  \
# 0     North Carolina   ACC  40  33  123.3   94.9   0.9531   52.6   48.1  15.4
# 1          Wisconsin   B10  40  36  129.1   93.6   0.9758   54.8   47.7  12.4
# 2           Michigan   B10  40  33  114.4   90.4   0.9375   53.9   47.7  14.0
# 3         Texas Tech   B12  38  31  115.2   85.2   0.9696   53.5   43.0  17.7
# 4            Gonzaga   WCC  39  37  117.8   86.3   0.9728   56.6   41.1  16.2
# ...              ...   ...  ..  ..    ...    ...      ...    ...    ...   ...
# 3518          Toledo   MAC  34  27  119.9  109.6   0.7369   56.3   52.9  13.6
# 3519         Liberty  ASun  33  27  111.4   97.3   0.8246   55.5   49.3  16.0
# 3520     Utah Valley   WAC  34  28  107.1   94.6   0.8065   51.7   44.0  19.3
# 3521             UAB  CUSA  38  29  112.4   97.0   0.8453   50.3   47.3  17.3
# 3522     North Texas  CUSA  36  31  110.0   93.8   0.8622   51.2   44.5  19.8
#
# ...
